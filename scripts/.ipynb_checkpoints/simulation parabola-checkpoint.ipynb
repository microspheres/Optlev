# %%
import numpy, h5py, matplotlib
import matplotlib.pyplot as plt
import os
import scipy.signal as sp
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.mlab as mlab
import dipole_fit_scale as dfs
import bead_util as bu
import glob, os
import correlation, h5py
import numpy as np
from matplotlib.mlab import psd
import matplotlib.pyplot as plt
from correlation import charge_of_electron
#from matplotlib.rcParams import update

distance_between_plates = 0.001 # meters

# %%
calib_path = "/data/20170622/bead4_15um_QWP/charge11"
data_path = "/data/20170622/bead4_15um_QWP/dipole27_Y" # this has the W
file_list = glob.glob(os.path.join(data_path, '*.h5'))
calib_list = bu.time_ordered_file_list(calib_path)
fnames = ["/data/20170511/Adam_simulation/gradient_angle.txt", "/data/20170511/Adam's simulation/New Text Document.txt"]

# %%
def getData(fname):
    """ assumes fname ends with a '.h5' 
        returns unitless data from file """
    gain, ACamp = correlation.getGainAndACamp(fname)
    f = h5py.File(fname, 'r')
    dset = f['beads/data/pos_data']
    dat = np.transpose(dset) # all this data is in volts
    dat = dat * 10./(2**15 - 1)
    x = dat[:,0]/gain
    x_data = ((x - np.average(x))/float(len(x))) # V

    drive = dat[:,7]
    drive_data = (drive - np.average(drive))/np.std(drive) # normalized, unitless drive

    return x_data, drive_data, ACamp

# %%
# Calibrate on one electron
corrs = []
i = min(5, len(calib_list))
for cname in calib_list[:i]:
    x_data, drive_data, acamp = getData(cname)
    N = acamp*charge_of_electron/distance_between_plates # newtons
    oc = np.correlate(x_data, drive_data) # V
    corrs.append(oc[0])
c_corr = np.average(corrs[:end_index])/N # V/N
print c_corr
# Out:
# 17149651.4371 -8.57623911816e+12

# %%
def parabola(x, a, b, c):
    """fit dipole ac field only at freq 2w"""
    return a*(x-b)**2+c

def order(A,B):
    return zip(*sorted(zip(A,B)))

# %%
for fname in fnames:
    
    print fname
    
    try:
        F0 = np.loadtxt(fname)
    except:
        continue
    
    F = np.transpose(F0)
    
    popt, pcov = curve_fit(parabola, F[0], F[1], bounds=([-5000., -0.002, 0.],[0., 0.002, 0.005]))
    
    print popt

    plt.figure()
    plt.plot(F[0], F[1], ".")
    plt.plot(F[0], parabola(F[0], *popt))
    plt.show()
# Out:
# /data/20170511/Adam_simulation/gradient_angle.txt
# [ -1.03819145e+03  -4.06308086e-06   6.47838465e-04]
# /data/20170511/Adam's simulation/New Text Document.txt
# [ -1.01668967e+03  -2.26241643e-06   6.10708267e-04]

# %%
F0 = np.loadtxt(fnames[0])
    
F = np.transpose(F0)

popt, pcov = curve_fit(parabola, F[0], -F[1], bounds=([0., -0.002, -0.005],[5000., 0.002, 0.005]))

print popt

plt.figure()
plt.plot(F[0], -F[1], ".")
plt.plot(F[0], parabola(F[0], *popt))
plt.xlabel('steps in theta [radians]')
plt.ylabel('gradient of electric field [m^-1]')
plt.grid()
plt.show()
# Out:
# [  1.03819144e+03  -4.06308085e-06  -6.47838423e-04]

# %%
# Get and plot calibrated data
peaks, positions, tf = ([] for i in range(3))
y_or_z = ""
for fname in file_list:
    x_data, drive_data, acamp, freqs, xpsd = getData(fname) # V, unitless, V, Hz, V^2/Hz

    position, y_or_z = correlation.outputThetaPosition(fname, y_or_z)
    positions.append(position)

    tc = np.correlate(x_data, drive_data**2) # V
    tf.append(tc[0]/c_corr) # N

positions, peaks, tf = zip(*sorted(zip(positions, peaks, tf)))
plt.plot(positions, peaks, 'o')
plt.plot(positions, tf, 'o')
plt.show()

# %%
pos_in_radians = np.array(positions)*4.0e-6

popt_t, pcov_t = curve_fit(parabola, pos_in_radians, tf, bounds=([0., -0.0035, -2.e-17],[1.2e-11, -0.001, 0.]))
print popt_t

plt.figure()
plt.plot(pos_in_radians, tf, ".")
plt.plot(pos_in_radians, parabola(pos_in_radians, *popt_t))
plt.xlabel('steps in theta [radians]')
plt.ylabel('gradient of electric field [m^-1]')
plt.grid()
plt.show()
# Out:
# [  6.00000000e-12  -2.25000000e-03  -1.00000000e-17]

# %%
import matplotlib
# %matplotlib notebook

plt.rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 20}
matplotlib.rc('font', **font)
matplotlib.rcParams['text.latex.preamble'] = [r'\boldmath']

plt.plot(F[0], -F[1], 'o')
plt.plot(F[0], parabola(F[0], *popt))

plt.xlabel('steps in theta [radians]', size=22)
plt.ylabel('gradient of electric field [m$^-1$]', size=22)
plt.legend(prop={'size': 22}, loc=2)

plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
