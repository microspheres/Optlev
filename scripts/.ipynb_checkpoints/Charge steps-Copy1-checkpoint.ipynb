# %%
import os, fnmatch, glob, h5py
from matplotlib.mlab import psd as get_psd_and_freqs
import numpy as np
import correlation
import matplotlib.pyplot as plt
import bead_util as bu
import matplotlib.pyplot as plt
import bead_util as bu
import numpy as np
import os, time

# %%
directory_names = []
for root, dirnames, filenames in os.walk('/data/'):
    for dirname in fnmatch.filter(dirnames, '*charge*'):
        if root[0:13]=='/data/2017071' or root[0:13]=='/data/2017070':
            directory_names.append(root+'/'+dirname)
directory_names = sorted(list(set(directory_names)))

# %%
directory_names
# Out:
# ['/data/20170703/bead3_15um_QWP/charge1',
#  '/data/20170703/bead3_15um_QWP/charge11',
#  '/data/20170703/bead3_15um_QWP/charge2',
#  '/data/20170703/bead3_15um_QWP/charge3',
#  '/data/20170703/bead3_15um_QWP/charge4',
#  '/data/20170703/bead3_15um_QWP/charge5',
#  '/data/20170703/bead3_15um_QWP/charge6',
#  '/data/20170703/bead3_15um_QWP/charge7',
#  '/data/20170703/bead3_15um_QWP/charge9',
#  '/data/20170704/bead2_15um_QWP/charge1',
#  '/data/20170704/bead2_15um_QWP/charge2',
#  '/data/20170704/bead2_15um_QWP/charge3',
#  '/data/20170704/bead2_15um_QWP/charge4',
#  '/data/20170704/bead2_15um_QWP/charge5',
#  '/data/20170704/bead2_15um_QWP/charge6',
#  '/data/20170705/bead2_15um_QWP/charge1',
#  '/data/20170705/bead4_15um_QWP/charge1',
#  '/data/20170705/bead4_15um_QWP/charge2',
#  '/data/20170705/bead4_15um_QWP/charge3',
#  '/data/20170705/bead4_15um_QWP/charge4',
#  '/data/20170705/bead4_15um_QWP/charge5',
#  '/data/20170705/bead4_15um_QWP/charge6',
# ...

# %%
def getdata(fname):
    #print "Processing ", fname
    dat, attribs, cf = bu.getdata(fname)
    fsamp = attribs["Fsamp"]
    xdat = dat[:, bu.xi]

    ## zero pad one cycle
    MinusDC = dat[:, bu.drive]
    corr_full = bu.corr_func(MinusDC - np.median(MinusDC), xdat, fsamp, fdrive)

    return corr_full[0]

# %%
for path in directory_names:
    print path
    
    corr_data = []
    
    for f in bu.time_ordered_file_list(path):
        try:
            corr_data.append(getdata(f))
        except:
            continue

    plt.plot(np.array(corr_data))
    plt.grid()
    plt.show()
# Out:
# /data/20170703/bead3_15um_QWP/charge1
# /data/20170703/bead3_15um_QWP/charge11
# /data/20170703/bead3_15um_QWP/charge2
# /data/20170703/bead3_15um_QWP/charge3
# Warning, got no keys for:  /data/20170703/bead3_15um_QWP/charge3/auto_xyzcool_G5_att_0.h5
# /data/20170703/bead3_15um_QWP/charge4
# /data/20170703/bead3_15um_QWP/charge5
# /data/20170703/bead3_15um_QWP/charge6
# /data/20170703/bead3_15um_QWP/charge7
# /data/20170703/bead3_15um_QWP/charge9
# /data/20170704/bead2_15um_QWP/charge1
# /data/20170704/bead2_15um_QWP/charge2
# Warning, got no keys for:  /data/20170704/bead2_15um_QWP/charge2/auto_xyzcool_G5_att_synth2000mV2000Hz0mVdc_112.h5
# /data/20170704/bead2_15um_QWP/charge3
# /data/20170704/bead2_15um_QWP/charge4
# /data/20170704/bead2_15um_QWP/charge5
# Warning, got no keys for:  /data/20170704/bead2_15um_QWP/charge5/auto_xyzcool_G100_att_synth100mV47Hz0mVdc_32.h5
# /data/20170704/bead2_15um_QWP/charge6
# /data/20170705/bead2_15um_QWP/charge1
# ...

# %%
# %matplotlib notebook
directory_names = ['/data/20170705/bead4_15um_QWP/charge8','/data/20170717/bead15_15um_QWP/charge5']
for path in directory_names:
    print path
    
    corr_data = []
    
    for f in bu.time_ordered_file_list(path):
        try:
            corr_data.append(getdata(f))
        except:
            continue

    plt.plot(np.array(corr_data))
    plt.grid()
    plt.show()
# Out:
# /data/20170705/bead4_15um_QWP/charge8
# Warning, got no keys for:  /data/20170705/bead4_15um_QWP/charge8/auto_xyzcool_G100_att_synth2mV47Hz0mVdc_218.h5
# <img src="data:image/png;base64,...">
# /data/20170717/bead15_15um_QWP/charge5

# %%
corr_data = []
    
for f in bu.time_ordered_file_list('/data/20170705/bead4_15um_QWP/charge8'):
    try:
        corr_data.append(getdata(f))
    except:
        continue

plt.plot(np.array(corr_data))
plt.grid()
plt.show()
# Out:
# Warning, got no keys for:  /data/20170705/bead4_15um_QWP/charge8/auto_xyzcool_G100_att_synth2mV47Hz0mVdc_218.h5
# <img src="data:image/png;base64,...">
